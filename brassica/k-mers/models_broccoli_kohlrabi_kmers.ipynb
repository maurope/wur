# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.ensemble import ExtraTreesRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
model = ExtraTreesRegressor(random_state=1)

# %% [markdown]
# # Loading Data

# %%
study = pd.read_csv('../brassica.csv')
study = study.drop(['crossovers', 'gametes', 'R', 'cM', 'gene', 'mRNA', 'exon', 'CDS'], axis = 1)
study = study.iloc[:,0:70] # Selecting columns with labels and k-mers counts
study
# Out:
#                        cross reference   chr     start       end        d  \
# 0       broccoli_cauliflower  broccoli  chr1         0    100000  0.00000
# 1       broccoli_cauliflower  broccoli  chr1    100000    200000  0.00000
# 2       broccoli_cauliflower  broccoli  chr1    200000    300000  0.00000
# 3       broccoli_cauliflower  broccoli  chr1    300000    400000  0.36497
# 4       broccoli_cauliflower  broccoli  chr1    400000    500000  0.00000
# ...                      ...       ...   ...       ...       ...      ...
# 103831        white_kohlrabi  kohlrabi  chr9  64400000  64500000  0.26316
# 103832        white_kohlrabi  kohlrabi  chr9  64500000  64600000  0.00000
# 103833        white_kohlrabi  kohlrabi  chr9  64600000  64700000  0.00000
# 103834        white_kohlrabi  kohlrabi  chr9  64700000  64800000  0.00000
# 103835        white_kohlrabi  kohlrabi  chr9  64800000  64900000  0.00000
#
#          AAA   AAC   AAG   AAT  ...  TCG   TCT   TGA   TGC   TGG   TGT   TTA  \
# 0       4884  2093  1508  3401  ...  758  2378  1552   882  1513  2010  2825
# 1       4192  1771  2066  2806  ...  889  2447  1959  1156  1358  1976  2447
# 2       4569  1884  1869  3102  ...  724  2139  2132   988  1437  1977  2988
# 3       4655  2071  1872  3026  ...  856  2339  1820   984  1238  1809  2746
# 4       4945  1924  1980  3122  ...  922  2280  1884   906  1250  1919  2783
# ...      ...   ...   ...   ...  ...  ...   ...   ...   ...   ...   ...   ...
# 103831  5056  2332  1546  3461  ...  665  2594  1825  1001  1296  1958  3030
# 103832  4649  2169  1725  2974  ...  658  2066  1814   966  1094  1888  3522
# 103833  4837  1937  2054  3112  ...  801  2030  1964   986  1239  1893  2833
# 103834  5965  1965  1907  3718  ...  622  1697  2234   858  1084  1893  3241
# 103835  5281  2104  1733  3356  ...  694  2032  2176   941  1237  1903  2948
#
#          TTC   TTG   TTT
# 0       2424  1812  5327
# 1       2234  2312  4415
# 2       2071  2348  5146
# 3       2284  2055  4928
# 4       2214  2158  4938
# ...      ...   ...   ...
# 103831  2138  2171  6190
# 103832  1985  1964  5452
# 103833  2092  2232  4736
# 103834  1696  2207  4896
# 103835  1850  2238  4993
#
# [103836 rows x 70 columns]

# %% [markdown]
# # Reverse-complements

# %%
df_original = study
df_new = df_original[['cross','reference','chr', 'start', 'end','d']].copy()

# List of complementary trimers
complementaries = {'A': 'T', 'T': 'A', 'C': 'G', 'G': 'C'}

# Set to track processed trimers
processed = set()

# Iterate over the columns of the original DataFrame
for column in df_original.columns[6:-1]:  # Start from the eleventh column
    trimer = column[:3]  # Get the current trimer (e.g., 'AAA')
    
    # Avoid processing the same trimer more than once
    if trimer not in processed:
        complementary = ''.join([complementaries[base] for base in reversed(trimer)])  # Get the complementary trimer (e.g., 'TTT')
        
        # Sum the corresponding columns and add a new column to the new DataFrame
        df_new[trimer + '_' + complementary] = df_original[trimer] + df_original[complementary]
        
        # Add the trimer and its complementary to the set of processed trimers
        processed.add(trimer)
        processed.add(complementary)
        
study2 = df_new

# %%
broccoli_kohlrabi = study2[study2['cross'] == 'broccoli_kohlrabi']
broccoli_kohlrabi = broccoli_kohlrabi.reset_index(drop=True)

# %%
# Applying smoothing to Kosambi recombination distances (column 'd') and creating a new column ('srec') containing the resulting smoothed values.
broccoli_kohlrabi['srec'] = 0 
for i in range (1, len(broccoli_kohlrabi)):
    if broccoli_kohlrabi.loc[i-1,'chr'] == broccoli_kohlrabi.loc[i,'chr']:
        broccoli_kohlrabi['srec'] = gaussian_filter(broccoli_kohlrabi['d'], sigma= 3)

# %%
b = broccoli_kohlrabi[broccoli_kohlrabi['reference']=='broccoli']

# %%
ko = broccoli_kohlrabi[broccoli_kohlrabi['reference']=='kohlrabi']

# %% [markdown]
# # BROCCOLI GENOME

# %% [markdown]
# # Data exploration

# %%
df = b

# %%
df_stats = df.drop(['cross', 'reference','chr','start','end','srec'],  axis=1)
df_stats_corr = df_stats.corr()['d'].sort_values(ascending = True)
df_corr = df_stats.corr()
df_corr = df_corr.iloc[1:, :]
fig = plt.figure(figsize=(15,9))
ax = fig.add_subplot(111)
df_corr['d'].sort_values(ascending = True).plot(kind = 'bar', color='skyblue', edgecolor='black')
ax.set_xlabel('Reverse complementary k-mers', fontsize=20)
ax.set_ylabel('Correlation with recombination rates', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=14)
plt.suptitle('Broccoli', fontsize=25)
plt.subplots_adjust(top=0.92)

plt.show()

# %% [markdown]
# # Chromosome Split

# %%
chr1 = df[df['chr']== 'chr1']
chr2 = df[df['chr']== 'chr2']
chr3 = df[df['chr']== 'chr3']
chr4 = df[df['chr']== 'chr4']
chr5 = df[df['chr']== 'chr5']
chr6 = df[df['chr']== 'chr6']
chr7 = df[df['chr']== 'chr7']
chr8 = df[df['chr']== 'chr8']
chr9 = df[df['chr']== 'chr9']

# %%
achr1 = df[df['chr']!= 'chr1']
achr2 = df[df['chr']!= 'chr2']
achr3 = df[df['chr']!= 'chr3']
achr4 = df[df['chr']!= 'chr4']
achr5 = df[df['chr']!= 'chr5']
achr6 = df[df['chr']!= 'chr6']
achr7 = df[df['chr']!= 'chr7']
achr8 = df[df['chr']!= 'chr8']
achr9 = df[df['chr']!= 'chr9']

# %% [markdown]
# # Function to train models and make graphs

# %% [markdown]
# The model is trained with the information of all chromosomes except the information of the chromosome to be predicted.

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chromosomes_data = globals()[f'achr{chr_number}']
    chr_data = globals()[f'chr{chr_number}']

    # TRAINING MODEL
    X_train = chromosomes_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1)
    y_train = chromosomes_data[['d']]

    model.fit(X_train, y_train)
    model_preds = model.predict(chr_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['srec'].iloc[0:c_q1]
    rq2 = chr_data['srec'].iloc[c_q1:c_q2]
    rq3 = chr_data['srec'].iloc[c_q2:c_q3]
    rq4 = chr_data['srec'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.srec, label='Recombination')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'Broccoli Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('chromosomes position (Mb)', fontsize=15)
    ax1.set_ylabel('Recombination rate (cM/100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.srec, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Recombination vs. Prediction', fontsize=15)
    ax2.set_xlabel('Recombination', fontsize=15)
    ax2.set_ylabel('Prediction', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.srec, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.srec, model_spreds)
    mse_chr = mean_squared_error(chr_data.srec, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.1)
    plt.show()

# %% [markdown]
# # Model Predictions

# %%
# Predictions for one chromosome, example: Chromosome 1
plot_chromosome_results(1)

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 10):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7,corr_chr8,corr_chr9,]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9',]})
b_table = pd.concat([index, corr, r2, mse], axis=1)
b_table
# Out:
#     chr      corr       R^2       MSE
# 0  chr1  0.788402  0.520488  0.007062
# 1  chr2  0.806154  0.516604  0.004009
# 2  chr3  0.644350  0.392718  0.003475
# 3  chr4  0.737393  0.493419  0.004856
# 4  chr5  0.728698  0.389942  0.015403
# 5  chr6  0.854372  0.563461  0.004266
# 6  chr7  0.849294  0.605062  0.002823
# 7  chr8  0.831664  0.643722  0.002657
# 8  chr9  0.820394  0.522378  0.007016

# %% [markdown]
# Correlation between model predictions and recombination rates by quartiles

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_010ae th {
#   text-align: center;
# }
# #T_010ae_row0_col1 {
#   background-color: #217d3b;
#   color: #f1f1f1;
# }
# #T_010ae_row0_col2 {
#   background-color: #166f32;
#   color: #f1f1f1;
# }
# #T_010ae_row0_col3 {
#   background-color: #f5f2f5;
#   color: #000000;
# }
# #T_010ae_row0_col4 {
#   background-color: #3f974f;
#   color: #f1f1f1;
# }
# #T_010ae_row1_col1, #T_010ae_row5_col4 {
#   background-color: #156d31;
#   color: #f1f1f1;
# }
# #T_010ae_row1_col2, #T_010ae_row1_col3 {
#   background-color: #f0e9f1;
#   color: #000000;
# }
# #T_010ae_row1_col4 {
#   background-color: #53a85c;
#   color: #f1f1f1;
# }
# #T_010ae_row2_col1 {
#   background-color: #58ac5f;
#   color: #f1f1f1;
# }
# #T_010ae_row2_col2, #T_010ae_row2_col3 {
#   background-color: #358e48;
#   color: #f1f1f1;
# }
# #T_010ae_row2_col4 {
#   background-color: #9fd79a;
#   color: #000000;
# }
# #T_010ae_row3_col1 {
#   background-color: #a2d89c;
#   color: #000000;
# }
# #T_010ae_row3_col2 {
#   background-color: #96d192;
#   color: #000000;
# }
# #T_010ae_row3_col3 {
#   background-color: #8aca89;
#   color: #000000;
# }
# #T_010ae_row3_col4 {
#   background-color: #0e5f29;
#   color: #f1f1f1;
# }
# #T_010ae_row4_col1 {
#   background-color: #60b266;
#   color: #f1f1f1;
# }
# #T_010ae_row4_col2 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_010ae_row4_col3 {
#   background-color: #eff5ee;
#   color: #000000;
# }
# #T_010ae_row4_col4 {
#   background-color: #11652d;
#   color: #f1f1f1;
# }
# #T_010ae_row5_col1 {
#   background-color: #5aae61;
#   color: #f1f1f1;
# }
# #T_010ae_row5_col2 {
#   background-color: #c1e6bb;
#   color: #000000;
# }
# #T_010ae_row5_col3 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_010ae_row6_col1 {
#   background-color: #f2ebf2;
#   color: #000000;
# }
# #T_010ae_row6_col2 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_010ae_row6_col3 {
#   background-color: #84c784;
#   color: #000000;
# }
# #T_010ae_row6_col4 {
#   background-color: #2e8843;
#   color: #f1f1f1;
# }
# #T_010ae_row7_col1 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_010ae_row7_col2 {
#   background-color: #499f55;
#   color: #f1f1f1;
# }
# #T_010ae_row7_col3 {
#   background-color: #50a65a;
#   color: #f1f1f1;
# }
# #T_010ae_row7_col4 {
#   background-color: #75be77;
#   color: #000000;
# }
# #T_010ae_row8_col1 {
#   background-color: #146b30;
#   color: #f1f1f1;
# }
# #T_010ae_row8_col2 {
#   background-color: #e7f3e4;
#   color: #000000;
# }
# #T_010ae_row8_col3 {
#   background-color: #c5e8bf;
#   color: #000000;
# }
# #T_010ae_row8_col4 {
#   background-color: #1f7b39;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_010ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_010ae_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_010ae_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_010ae_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_010ae_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_010ae_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_010ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_010ae_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_010ae_row0_col1" class="data row0 col1" >0.780053</td>
#       <td id="T_010ae_row0_col2" class="data row0 col2" >0.833798</td>
#       <td id="T_010ae_row0_col3" class="data row0 col3" >-0.028281</td>
#       <td id="T_010ae_row0_col4" class="data row0 col4" >0.685253</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_010ae_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_010ae_row1_col1" class="data row1 col1" >0.839702</td>
#       <td id="T_010ae_row1_col2" class="data row1 col2" >-0.083273</td>
#       <td id="T_010ae_row1_col3" class="data row1 col3" >-0.082973</td>
#       <td id="T_010ae_row1_col4" class="data row1 col4" >0.619255</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_010ae_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_010ae_row2_col1" class="data row2 col1" >0.603744</td>
#       <td id="T_010ae_row2_col2" class="data row2 col2" >0.718168</td>
#       <td id="T_010ae_row2_col3" class="data row2 col3" >0.717660</td>
#       <td id="T_010ae_row2_col4" class="data row2 col4" >0.419180</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_010ae_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_010ae_row3_col1" class="data row3 col1" >0.411589</td>
#       <td id="T_010ae_row3_col2" class="data row3 col2" >0.440353</td>
#       <td id="T_010ae_row3_col3" class="data row3 col3" >0.469118</td>
#       <td id="T_010ae_row3_col4" class="data row3 col4" >0.895244</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_010ae_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_010ae_row4_col1" class="data row4 col1" >0.582823</td>
#       <td id="T_010ae_row4_col2" class="data row4 col2" >0.196889</td>
#       <td id="T_010ae_row4_col3" class="data row4 col3" >0.048035</td>
#       <td id="T_010ae_row4_col4" class="data row4 col4" >0.872358</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_010ae_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_010ae_row5_col1" class="data row5 col1" >0.601127</td>
#       <td id="T_010ae_row5_col2" class="data row5 col2" >0.289439</td>
#       <td id="T_010ae_row5_col3" class="data row5 col3" >0.379844</td>
#       <td id="T_010ae_row5_col4" class="data row5 col4" >0.842399</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_010ae_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_010ae_row6_col1" class="data row6 col1" >-0.067958</td>
#       <td id="T_010ae_row6_col2" class="data row6 col2" >0.224893</td>
#       <td id="T_010ae_row6_col3" class="data row6 col3" >0.491765</td>
#       <td id="T_010ae_row6_col4" class="data row6 col4" >0.737895</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_010ae_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_010ae_row7_col1" class="data row7 col1" >0.209613</td>
#       <td id="T_010ae_row7_col2" class="data row7 col2" >0.654370</td>
#       <td id="T_010ae_row7_col3" class="data row7 col3" >0.630629</td>
#       <td id="T_010ae_row7_col4" class="data row7 col4" >0.525671</td>
#     </tr>
#     <tr>
#       <th id="T_010ae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_010ae_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_010ae_row8_col1" class="data row8 col1" >0.851338</td>
#       <td id="T_010ae_row8_col2" class="data row8 col2" >0.104202</td>
#       <td id="T_010ae_row8_col3" class="data row8 col3" >0.276592</td>
#       <td id="T_010ae_row8_col4" class="data row8 col4" >0.785376</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # KOHLRABI GENOME

# %% [markdown]
# # Data exploration

# %%
df = ko

# %%
df_stats = df.drop(['cross', 'reference','chr','start','end','srec'],  axis=1)
df_stats_corr = df_stats.corr()['d'].sort_values(ascending = True)
df_corr = df_stats.corr()
df_corr = df_corr.iloc[1:, :]
fig = plt.figure(figsize=(15,9))
ax = fig.add_subplot(111)
df_corr['d'].sort_values(ascending = True).plot(kind = 'bar', color='skyblue', edgecolor='black')
ax.set_xlabel('Reverse complementary k-mers', fontsize=20)
ax.set_ylabel('Correlation with recombination rates', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=14)
plt.suptitle('Kohlrabi', fontsize=25)
plt.subplots_adjust(top=0.92)

plt.show()

# %% [markdown]
# # Chromosome Split

# %%
chr1 = df[df['chr']== 'chr1']
chr2 = df[df['chr']== 'chr2']
chr3 = df[df['chr']== 'chr3']
chr4 = df[df['chr']== 'chr4']
chr5 = df[df['chr']== 'chr5']
chr6 = df[df['chr']== 'chr6']
chr7 = df[df['chr']== 'chr7']
chr8 = df[df['chr']== 'chr8']
chr9 = df[df['chr']== 'chr9']

# %%
achr1 = df[df['chr']!= 'chr1']
achr2 = df[df['chr']!= 'chr2']
achr3 = df[df['chr']!= 'chr3']
achr4 = df[df['chr']!= 'chr4']
achr5 = df[df['chr']!= 'chr5']
achr6 = df[df['chr']!= 'chr6']
achr7 = df[df['chr']!= 'chr7']
achr8 = df[df['chr']!= 'chr8']
achr9 = df[df['chr']!= 'chr9']

# %% [markdown]
# # Function to train models and make graphs

# %% [markdown]
# The model is trained with the information of all chromosomes except the information of the chromosome to be predicted.

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chromosomes_data = globals()[f'achr{chr_number}']
    chr_data = globals()[f'chr{chr_number}']

    # TRAINING MODEL
    X_train = chromosomes_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1)
    y_train = chromosomes_data[['d']]
    
    model.fit(X_train, y_train)
    model_preds = model.predict(chr_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['srec'].iloc[0:c_q1]
    rq2 = chr_data['srec'].iloc[c_q1:c_q2]
    rq3 = chr_data['srec'].iloc[c_q2:c_q3]
    rq4 = chr_data['srec'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.srec, label='Recombination')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'Kohlrabi Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('chromosomes position (Mb)', fontsize=15)
    ax1.set_ylabel('Recombination rate (cM/100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.srec, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Recombination vs. Prediction', fontsize=15)
    ax2.set_xlabel('Recombination', fontsize=15)
    ax2.set_ylabel('Prediction', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.srec, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.srec, model_spreds)
    mse_chr = mean_squared_error(chr_data.srec, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.1)
    plt.show()

# %% [markdown]
# # Model Predictions

# %%
# For one chromosome, example Chromosome 1
plot_chromosome_results(1)

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 10):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7,corr_chr8,corr_chr9,]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9',]})
ko_table = pd.concat([index, corr, r2, mse], axis=1)
ko_table
# Out:
#     chr      corr       R^2       MSE
# 0  chr1  0.745346  0.426917  0.008562
# 1  chr2  0.764398  0.481878  0.003892
# 2  chr3  0.593062  0.323856  0.003623
# 3  chr4  0.744328  0.478807  0.004782
# 4  chr5  0.722906  0.394210  0.015118
# 5  chr6  0.791262  0.491362  0.004622
# 6  chr7  0.837509  0.592814  0.002647
# 7  chr8  0.808050  0.593618  0.003066
# 8  chr9  0.790701  0.519009  0.006551

# %% [markdown]
# Correlation between model predictions and recombination rates by quartiles

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_cb420 th {
#   text-align: center;
# }
# #T_cb420_row0_col1 {
#   background-color: #298440;
#   color: #f1f1f1;
# }
# #T_cb420_row0_col2 {
#   background-color: #2e8843;
#   color: #f1f1f1;
# }
# #T_cb420_row0_col3 {
#   background-color: #f3eef3;
#   color: #000000;
# }
# #T_cb420_row0_col4 {
#   background-color: #66b56b;
#   color: #f1f1f1;
# }
# #T_cb420_row1_col1 {
#   background-color: #217d3b;
#   color: #f1f1f1;
# }
# #T_cb420_row1_col2 {
#   background-color: #ebdeec;
#   color: #000000;
# }
# #T_cb420_row1_col3 {
#   background-color: #e1cde4;
#   color: #000000;
# }
# #T_cb420_row1_col4 {
#   background-color: #53a85c;
#   color: #f1f1f1;
# }
# #T_cb420_row2_col1 {
#   background-color: #55aa5e;
#   color: #f1f1f1;
# }
# #T_cb420_row2_col2 {
#   background-color: #3f974f;
#   color: #f1f1f1;
# }
# #T_cb420_row2_col3 {
#   background-color: #499f55;
#   color: #f1f1f1;
# }
# #T_cb420_row2_col4 {
#   background-color: #dff1da;
#   color: #000000;
# }
# #T_cb420_row3_col1 {
#   background-color: #90ce8d;
#   color: #000000;
# }
# #T_cb420_row3_col2, #T_cb420_row3_col3, #T_cb420_row7_col4 {
#   background-color: #6cb970;
#   color: #f1f1f1;
# }
# #T_cb420_row3_col4 {
#   background-color: #146b30;
#   color: #f1f1f1;
# }
# #T_cb420_row4_col1 {
#   background-color: #5aae61;
#   color: #f1f1f1;
# }
# #T_cb420_row4_col2 {
#   background-color: #c5e8bf;
#   color: #000000;
# }
# #T_cb420_row4_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_cb420_row4_col4, #T_cb420_row8_col1 {
#   background-color: #166f32;
#   color: #f1f1f1;
# }
# #T_cb420_row5_col1, #T_cb420_row6_col2 {
#   background-color: #cbeac5;
#   color: #000000;
# }
# #T_cb420_row5_col2 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_cb420_row5_col3 {
#   background-color: #5db063;
#   color: #f1f1f1;
# }
# #T_cb420_row5_col4 {
#   background-color: #2b8642;
#   color: #f1f1f1;
# }
# #T_cb420_row6_col1 {
#   background-color: #f2edf3;
#   color: #000000;
# }
# #T_cb420_row6_col3 {
#   background-color: #81c581;
#   color: #000000;
# }
# #T_cb420_row6_col4, #T_cb420_row7_col2 {
#   background-color: #469d54;
#   color: #f1f1f1;
# }
# #T_cb420_row7_col1 {
#   background-color: #f3f6f2;
#   color: #000000;
# }
# #T_cb420_row7_col3 {
#   background-color: #58ac5f;
#   color: #f1f1f1;
# }
# #T_cb420_row8_col2 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_cb420_row8_col3 {
#   background-color: #bde4b7;
#   color: #000000;
# }
# #T_cb420_row8_col4 {
#   background-color: #419951;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb420">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb420_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_cb420_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_cb420_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_cb420_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_cb420_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb420_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb420_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_cb420_row0_col1" class="data row0 col1" >0.756822</td>
#       <td id="T_cb420_row0_col2" class="data row0 col2" >0.741796</td>
#       <td id="T_cb420_row0_col3" class="data row0 col3" >-0.050611</td>
#       <td id="T_cb420_row0_col4" class="data row0 col4" >0.567678</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb420_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_cb420_row1_col1" class="data row1 col1" >0.773520</td>
#       <td id="T_cb420_row1_col2" class="data row1 col2" >-0.142840</td>
#       <td id="T_cb420_row1_col3" class="data row1 col3" >-0.230765</td>
#       <td id="T_cb420_row1_col4" class="data row1 col4" >0.623933</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb420_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_cb420_row2_col1" class="data row2 col1" >0.611225</td>
#       <td id="T_cb420_row2_col2" class="data row2 col2" >0.685371</td>
#       <td id="T_cb420_row2_col3" class="data row2 col3" >0.654800</td>
#       <td id="T_cb420_row2_col4" class="data row2 col4" >0.159223</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb420_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_cb420_row3_col1" class="data row3 col1" >0.453632</td>
#       <td id="T_cb420_row3_col2" class="data row3 col2" >0.550074</td>
#       <td id="T_cb420_row3_col3" class="data row3 col3" >0.553244</td>
#       <td id="T_cb420_row3_col4" class="data row3 col4" >0.847369</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb420_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_cb420_row4_col1" class="data row4 col1" >0.597938</td>
#       <td id="T_cb420_row4_col2" class="data row4 col2" >0.280504</td>
#       <td id="T_cb420_row4_col3" class="data row4 col3" >0.201596</td>
#       <td id="T_cb420_row4_col4" class="data row4 col4" >0.830566</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb420_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_cb420_row5_col1" class="data row5 col1" >0.251753</td>
#       <td id="T_cb420_row5_col2" class="data row5 col2" >0.207420</td>
#       <td id="T_cb420_row5_col3" class="data row5 col3" >0.587372</td>
#       <td id="T_cb420_row5_col4" class="data row5 col4" >0.749980</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb420_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_cb420_row6_col1" class="data row6 col1" >-0.054882</td>
#       <td id="T_cb420_row6_col2" class="data row6 col2" >0.254064</td>
#       <td id="T_cb420_row6_col3" class="data row6 col3" >0.492850</td>
#       <td id="T_cb420_row6_col4" class="data row6 col4" >0.660521</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb420_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_cb420_row7_col1" class="data row7 col1" >0.024672</td>
#       <td id="T_cb420_row7_col2" class="data row7 col2" >0.663830</td>
#       <td id="T_cb420_row7_col3" class="data row7 col3" >0.603307</td>
#       <td id="T_cb420_row7_col4" class="data row7 col4" >0.547756</td>
#     </tr>
#     <tr>
#       <th id="T_cb420_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb420_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_cb420_row8_col1" class="data row8 col1" >0.832997</td>
#       <td id="T_cb420_row8_col2" class="data row8 col2" >0.329234</td>
#       <td id="T_cb420_row8_col3" class="data row8 col3" >0.312019</td>
#       <td id="T_cb420_row8_col4" class="data row8 col4" >0.674895</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Prediction performance of models trained with Broccoli data and Kohlrabi data.

# %%
# Adjusting bar width
bar_width = 0.35

# Creating data positions
bar_positions_b = np.arange(len(b_table['chr']))
bar_positions_ko = bar_positions_b + bar_width

# Creating subplots (1 row, 3 columns)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# First chart
axs[0].bar(bar_positions_b, b_table['corr'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[0].bar(bar_positions_ko, ko_table['corr'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)

axs[0].set_ylabel('Correlation', fontsize=15)

# Second chart
axs[1].bar(bar_positions_b, b_table['R^2'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[1].bar(bar_positions_ko, ko_table['R^2'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)

axs[1].set_ylabel('Coefficient of determination', fontsize=15)

# Third chart
axs[2].bar(bar_positions_b, b_table['MSE'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[2].bar(bar_positions_ko, ko_table['MSE'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)

axs[2].set_ylabel('Mean Squared Error', fontsize=15)

# Get chromosome labels from the 'chr' column
chr_labels = ko_table['chr']

# Set x-axis labels for all three subplots
for ax in axs:
    ax.set_xticks(bar_positions_b)
    ax.set_xticklabels(chr_labels)

# Rotate labels for better readability
for ax in axs:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Adjusting layout
plt.tight_layout()

# Place legend outside the subplots and above the last subplot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)

# Show the figure
plt.show()

# %% [markdown]
# # Model trained with all Broccoli chromosomes to predict recombination on each Kohlrabi chromosome

# %%
# TRAINING MODEL with Broccoli data
X_train = b.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1)
y_train = b[['d']]

model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %%
# Objects with Kohlrabi data per chromosome
chr1 = ko[ko['chr']== 'chr1']
chr2 = ko[ko['chr']== 'chr2']
chr3 = ko[ko['chr']== 'chr3']
chr4 = ko[ko['chr']== 'chr4']
chr5 = ko[ko['chr']== 'chr5']
chr6 = ko[ko['chr']== 'chr6']
chr7 = ko[ko['chr']== 'chr7']
chr8 = ko[ko['chr']== 'chr8']
chr9 = ko[ko['chr']== 'chr9']

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chromosomes_data = globals()[f'achr{chr_number}']
    chr_data = globals()[f'chr{chr_number}']

    # MODEL PREDICTIONS
    model_preds = model.predict(chr_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['srec'].iloc[0:c_q1]
    rq2 = chr_data['srec'].iloc[c_q1:c_q2]
    rq3 = chr_data['srec'].iloc[c_q2:c_q3]
    rq4 = chr_data['srec'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.srec, label='Recombination')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'Kohlrabi Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('chromosomes position (Mb)', fontsize=15)
    ax1.set_ylabel('Recombination rate (cM/100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.srec, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Recombination vs. Prediction', fontsize=15)
    ax2.set_xlabel('Recombination', fontsize=15)
    ax2.set_ylabel('Prediction', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.srec, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.srec, model_spreds)
    mse_chr = mean_squared_error(chr_data.srec, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.1)
    plt.show()

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 10):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7,corr_chr8,corr_chr9,]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9',]})
tb_pko_table = pd.concat([index, corr, r2, mse], axis=1)
tb_pko_table
# Out:
#     chr      corr       R^2       MSE
# 0  chr1  0.826776  0.553556  0.006670
# 1  chr2  0.785746  0.509358  0.003685
# 2  chr3  0.651129  0.395097  0.003241
# 3  chr4  0.784409  0.540237  0.004218
# 4  chr5  0.748432  0.436210  0.014070
# 5  chr6  0.836666  0.557281  0.004023
# 6  chr7  0.872526  0.659684  0.002212
# 7  chr8  0.831051  0.629598  0.002795
# 8  chr9  0.832208  0.579704  0.005725

# %% [markdown]
# Correlation between model predictions and recombination rates by quartiles

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_1806e th {
#   text-align: center;
# }
# #T_1806e_row0_col1 {
#   background-color: #146b30;
#   color: #f1f1f1;
# }
# #T_1806e_row0_col2, #T_1806e_row6_col4 {
#   background-color: #197535;
#   color: #f1f1f1;
# }
# #T_1806e_row0_col3 {
#   background-color: #f6f7f6;
#   color: #000000;
# }
# #T_1806e_row0_col4 {
#   background-color: #2b8642;
#   color: #f1f1f1;
# }
# #T_1806e_row1_col1 {
#   background-color: #187334;
#   color: #f1f1f1;
# }
# #T_1806e_row1_col2 {
#   background-color: #d3bada;
#   color: #000000;
# }
# #T_1806e_row1_col3 {
#   background-color: #e7d4e8;
#   color: #000000;
# }
# #T_1806e_row1_col4 {
#   background-color: #5aae61;
#   color: #f1f1f1;
# }
# #T_1806e_row2_col1 {
#   background-color: #4ea359;
#   color: #f1f1f1;
# }
# #T_1806e_row2_col2 {
#   background-color: #1f7b39;
#   color: #f1f1f1;
# }
# #T_1806e_row2_col3 {
#   background-color: #358e48;
#   color: #f1f1f1;
# }
# #T_1806e_row2_col4 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_1806e_row3_col1 {
#   background-color: #72bc75;
#   color: #000000;
# }
# #T_1806e_row3_col2 {
#   background-color: #60b266;
#   color: #f1f1f1;
# }
# #T_1806e_row3_col3, #T_1806e_row7_col2 {
#   background-color: #53a85c;
#   color: #f1f1f1;
# }
# #T_1806e_row3_col4 {
#   background-color: #13692f;
#   color: #f1f1f1;
# }
# #T_1806e_row4_col1 {
#   background-color: #469d54;
#   color: #f1f1f1;
# }
# #T_1806e_row4_col2 {
#   background-color: #e0f2db;
#   color: #000000;
# }
# #T_1806e_row4_col3 {
#   background-color: #e5f3e1;
#   color: #000000;
# }
# #T_1806e_row4_col4 {
#   background-color: #177133;
#   color: #f1f1f1;
# }
# #T_1806e_row5_col1 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_1806e_row5_col2, #T_1806e_row8_col2 {
#   background-color: #a7dba1;
#   color: #000000;
# }
# #T_1806e_row5_col3 {
#   background-color: #50a65a;
#   color: #f1f1f1;
# }
# #T_1806e_row5_col4 {
#   background-color: #166f32;
#   color: #f1f1f1;
# }
# #T_1806e_row6_col1 {
#   background-color: #f7f6f7;
#   color: #000000;
# }
# #T_1806e_row6_col2 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_1806e_row6_col3 {
#   background-color: #a2d89c;
#   color: #000000;
# }
# #T_1806e_row7_col1 {
#   background-color: #f2f6f1;
#   color: #000000;
# }
# #T_1806e_row7_col3 {
#   background-color: #75be77;
#   color: #000000;
# }
# #T_1806e_row7_col4 {
#   background-color: #58ac5f;
#   color: #f1f1f1;
# }
# #T_1806e_row8_col1 {
#   background-color: #0f612a;
#   color: #f1f1f1;
# }
# #T_1806e_row8_col3 {
#   background-color: #7bc17c;
#   color: #000000;
# }
# #T_1806e_row8_col4 {
#   background-color: #26823e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1806e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1806e_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_1806e_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_1806e_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_1806e_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_1806e_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1806e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1806e_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_1806e_row0_col1" class="data row0 col1" >0.845047</td>
#       <td id="T_1806e_row0_col2" class="data row0 col2" >0.809865</td>
#       <td id="T_1806e_row0_col3" class="data row0 col3" >0.002695</td>
#       <td id="T_1806e_row0_col4" class="data row0 col4" >0.748819</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1806e_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_1806e_row1_col1" class="data row1 col1" >0.814259</td>
#       <td id="T_1806e_row1_col2" class="data row1 col2" >-0.310342</td>
#       <td id="T_1806e_row1_col3" class="data row1 col3" >-0.195694</td>
#       <td id="T_1806e_row1_col4" class="data row1 col4" >0.599265</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1806e_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_1806e_row2_col1" class="data row2 col1" >0.634771</td>
#       <td id="T_1806e_row2_col2" class="data row2 col2" >0.788816</td>
#       <td id="T_1806e_row2_col3" class="data row2 col3" >0.714449</td>
#       <td id="T_1806e_row2_col4" class="data row2 col4" >0.379733</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1806e_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_1806e_row3_col1" class="data row3 col1" >0.534046</td>
#       <td id="T_1806e_row3_col2" class="data row3 col2" >0.582287</td>
#       <td id="T_1806e_row3_col3" class="data row3 col3" >0.624375</td>
#       <td id="T_1806e_row3_col4" class="data row3 col4" >0.857224</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1806e_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_1806e_row4_col1" class="data row4 col1" >0.661312</td>
#       <td id="T_1806e_row4_col2" class="data row4 col2" >0.152329</td>
#       <td id="T_1806e_row4_col3" class="data row4 col3" >0.123837</td>
#       <td id="T_1806e_row4_col4" class="data row4 col4" >0.825118</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1806e_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_1806e_row5_col1" class="data row5 col1" >0.329970</td>
#       <td id="T_1806e_row5_col2" class="data row5 col2" >0.397154</td>
#       <td id="T_1806e_row5_col3" class="data row5 col3" >0.627195</td>
#       <td id="T_1806e_row5_col4" class="data row5 col4" >0.829397</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1806e_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_1806e_row6_col1" class="data row6 col1" >-0.001981</td>
#       <td id="T_1806e_row6_col2" class="data row6 col2" >0.314692</td>
#       <td id="T_1806e_row6_col3" class="data row6 col3" >0.408801</td>
#       <td id="T_1806e_row6_col4" class="data row6 col4" >0.809398</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1806e_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_1806e_row7_col1" class="data row7 col1" >0.031939</td>
#       <td id="T_1806e_row7_col2" class="data row7 col2" >0.622373</td>
#       <td id="T_1806e_row7_col3" class="data row7 col3" >0.530831</td>
#       <td id="T_1806e_row7_col4" class="data row7 col4" >0.608170</td>
#     </tr>
#     <tr>
#       <th id="T_1806e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1806e_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_1806e_row8_col1" class="data row8 col1" >0.890357</td>
#       <td id="T_1806e_row8_col2" class="data row8 col2" >0.393201</td>
#       <td id="T_1806e_row8_col3" class="data row8 col3" >0.515139</td>
#       <td id="T_1806e_row8_col4" class="data row8 col4" >0.760842</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Model trained with all Kohlrabi chromosomes to predict recombination on each Broccoli chromosome

# %%
# TRAINING MODEL with Kohlrabi data
X_train = ko.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1)
y_train = ko[['d']]

model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %%
# Objects with Broccoli data per chromosome
chr1 = b[b['chr']== 'chr1']
chr2 = b[b['chr']== 'chr2']
chr3 = b[b['chr']== 'chr3']
chr4 = b[b['chr']== 'chr4']
chr5 = b[b['chr']== 'chr5']
chr6 = b[b['chr']== 'chr6']
chr7 = b[b['chr']== 'chr7']
chr8 = b[b['chr']== 'chr8']
chr9 = b[b['chr']== 'chr9']

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chromosomes_data = globals()[f'achr{chr_number}']
    chr_data = globals()[f'chr{chr_number}']

    # MODEL PREDICTIONS
    model_preds = model.predict(chr_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['srec'].iloc[0:c_q1]
    rq2 = chr_data['srec'].iloc[c_q1:c_q2]
    rq3 = chr_data['srec'].iloc[c_q2:c_q3]
    rq4 = chr_data['srec'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.srec, label='Recombination')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'Broccoli Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('chromosomes position (Mb)', fontsize=15)
    ax1.set_ylabel('Recombination rate (cM/100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.srec, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Recombination vs. Prediction', fontsize=15)
    ax2.set_xlabel('Recombination', fontsize=15)
    ax2.set_ylabel('Prediction', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.srec, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.srec, model_spreds)
    mse_chr = mean_squared_error(chr_data.srec, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.1)
    plt.show()

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 10):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7,corr_chr8,corr_chr9,]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9',]})
tko_pb_table = pd.concat([index, corr, r2, mse], axis=1)
tko_pb_table
# Out:
#     chr      corr       R^2       MSE
# 0  chr1  0.770222  0.482850  0.007617
# 1  chr2  0.808638  0.528118  0.003913
# 2  chr3  0.630873  0.394021  0.003468
# 3  chr4  0.796113  0.534524  0.004462
# 4  chr5  0.730016  0.419507  0.014656
# 5  chr6  0.863025  0.562927  0.004271
# 6  chr7  0.876963  0.660124  0.002430
# 7  chr8  0.851192  0.673371  0.002436
# 8  chr9  0.868656  0.607712  0.005762

# %% [markdown]
# Correlation between model predictions and recombination rates by quartiles

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_222fe th {
#   text-align: center;
# }
# #T_222fe_row0_col1 {
#   background-color: #1c7938;
#   color: #f1f1f1;
# }
# #T_222fe_row0_col2 {
#   background-color: #1a7736;
#   color: #f1f1f1;
# }
# #T_222fe_row0_col3, #T_222fe_row7_col1 {
#   background-color: #def1d9;
#   color: #000000;
# }
# #T_222fe_row0_col4 {
#   background-color: #4ba157;
#   color: #f1f1f1;
# }
# #T_222fe_row1_col1 {
#   background-color: #197535;
#   color: #f1f1f1;
# }
# #T_222fe_row1_col2 {
#   background-color: #ede0ed;
#   color: #000000;
# }
# #T_222fe_row1_col3 {
#   background-color: #f1f5ef;
#   color: #000000;
# }
# #T_222fe_row1_col4, #T_222fe_row7_col3 {
#   background-color: #53a85c;
#   color: #f1f1f1;
# }
# #T_222fe_row2_col1 {
#   background-color: #419951;
#   color: #f1f1f1;
# }
# #T_222fe_row2_col2 {
#   background-color: #3a924c;
#   color: #f1f1f1;
# }
# #T_222fe_row2_col3 {
#   background-color: #55aa5e;
#   color: #f1f1f1;
# }
# #T_222fe_row2_col4 {
#   background-color: #c3e7bd;
#   color: #000000;
# }
# #T_222fe_row3_col1, #T_222fe_row5_col1 {
#   background-color: #7bc17c;
#   color: #000000;
# }
# #T_222fe_row3_col2, #T_222fe_row5_col3 {
#   background-color: #69b76d;
#   color: #f1f1f1;
# }
# #T_222fe_row3_col3 {
#   background-color: #b5e1af;
#   color: #000000;
# }
# #T_222fe_row3_col4, #T_222fe_row8_col1 {
#   background-color: #0e5f29;
#   color: #f1f1f1;
# }
# #T_222fe_row4_col1 {
#   background-color: #5aae61;
#   color: #f1f1f1;
# }
# #T_222fe_row4_col2 {
#   background-color: #b3e0ad;
#   color: #000000;
# }
# #T_222fe_row4_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_222fe_row4_col4 {
#   background-color: #156d31;
#   color: #f1f1f1;
# }
# #T_222fe_row5_col2 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_222fe_row5_col4 {
#   background-color: #11652d;
#   color: #f1f1f1;
# }
# #T_222fe_row6_col1 {
#   background-color: #eef5ec;
#   color: #000000;
# }
# #T_222fe_row6_col2 {
#   background-color: #bfe5b9;
#   color: #000000;
# }
# #T_222fe_row6_col3 {
#   background-color: #81c581;
#   color: #000000;
# }
# #T_222fe_row6_col4 {
#   background-color: #146b30;
#   color: #f1f1f1;
# }
# #T_222fe_row7_col2 {
#   background-color: #1f7b39;
#   color: #f1f1f1;
# }
# #T_222fe_row7_col4 {
#   background-color: #469d54;
#   color: #f1f1f1;
# }
# #T_222fe_row8_col2 {
#   background-color: #e5f3e1;
#   color: #000000;
# }
# #T_222fe_row8_col3 {
#   background-color: #c9e9c3;
#   color: #000000;
# }
# #T_222fe_row8_col4 {
#   background-color: #166f32;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_222fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_222fe_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_222fe_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_222fe_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_222fe_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_222fe_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_222fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_222fe_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_222fe_row0_col1" class="data row0 col1" >0.793217</td>
#       <td id="T_222fe_row0_col2" class="data row0 col2" >0.804454</td>
#       <td id="T_222fe_row0_col3" class="data row0 col3" >0.166923</td>
#       <td id="T_222fe_row0_col4" class="data row0 col4" >0.640885</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_222fe_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_222fe_row1_col1" class="data row1 col1" >0.809493</td>
#       <td id="T_222fe_row1_col2" class="data row1 col2" >-0.128814</td>
#       <td id="T_222fe_row1_col3" class="data row1 col3" >0.040955</td>
#       <td id="T_222fe_row1_col4" class="data row1 col4" >0.618738</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_222fe_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_222fe_row2_col1" class="data row2 col1" >0.676535</td>
#       <td id="T_222fe_row2_col2" class="data row2 col2" >0.698880</td>
#       <td id="T_222fe_row2_col3" class="data row2 col3" >0.614617</td>
#       <td id="T_222fe_row2_col4" class="data row2 col4" >0.282458</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_222fe_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_222fe_row3_col1" class="data row3 col1" >0.514806</td>
#       <td id="T_222fe_row3_col2" class="data row3 col2" >0.557637</td>
#       <td id="T_222fe_row3_col3" class="data row3 col3" >0.338869</td>
#       <td id="T_222fe_row3_col4" class="data row3 col4" >0.890857</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_222fe_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_222fe_row4_col1" class="data row4 col1" >0.601241</td>
#       <td id="T_222fe_row4_col2" class="data row4 col2" >0.344002</td>
#       <td id="T_222fe_row4_col3" class="data row4 col3" >0.199664</td>
#       <td id="T_222fe_row4_col4" class="data row4 col4" >0.842750</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_222fe_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_222fe_row5_col1" class="data row5 col1" >0.515402</td>
#       <td id="T_222fe_row5_col2" class="data row5 col2" >0.238433</td>
#       <td id="T_222fe_row5_col3" class="data row5 col3" >0.562334</td>
#       <td id="T_222fe_row5_col4" class="data row5 col4" >0.873060</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_222fe_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_222fe_row6_col1" class="data row6 col1" >0.055765</td>
#       <td id="T_222fe_row6_col2" class="data row6 col2" >0.302019</td>
#       <td id="T_222fe_row6_col3" class="data row6 col3" >0.499640</td>
#       <td id="T_222fe_row6_col4" class="data row6 col4" >0.845357</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_222fe_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_222fe_row7_col1" class="data row7 col1" >0.166341</td>
#       <td id="T_222fe_row7_col2" class="data row7 col2" >0.785542</td>
#       <td id="T_222fe_row7_col3" class="data row7 col3" >0.623186</td>
#       <td id="T_222fe_row7_col4" class="data row7 col4" >0.656560</td>
#     </tr>
#     <tr>
#       <th id="T_222fe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_222fe_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_222fe_row8_col1" class="data row8 col1" >0.892324</td>
#       <td id="T_222fe_row8_col2" class="data row8 col2" >0.123197</td>
#       <td id="T_222fe_row8_col3" class="data row8 col3" >0.260659</td>
#       <td id="T_222fe_row8_col4" class="data row8 col4" >0.835285</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Four model comparison

# %%
# Adjusting bar width
bar_width = 0.2

# Creating data positions
bar_positions_b = np.arange(len(b_table['chr']))
bar_positions_ko = bar_positions_b + bar_width
bar_positions_tb_pko = bar_positions_ko + bar_width
bar_positions_tko_pb = bar_positions_tb_pko + bar_width

# Creating subplots (1 row, 3 columns)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# First chart
axs[0].bar(bar_positions_b, b_table['corr'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[0].bar(bar_positions_ko, ko_table['corr'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)
axs[0].bar(bar_positions_tb_pko, tb_pko_table['corr'], color='red', width=bar_width, label='tB_pKo', alpha=0.7)
axs[0].bar(bar_positions_tko_pb, tko_pb_table['corr'], color='purple', width=bar_width, label='tKo_pB', alpha=0.7)

axs[0].set_ylabel('Correlation', fontsize=15)

# Second chart

axs[1].bar(bar_positions_b, b_table['R^2'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[1].bar(bar_positions_ko, ko_table['R^2'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)
axs[1].bar(bar_positions_tb_pko, tb_pko_table['R^2'], color='red', width=bar_width, label='tB_pKo', alpha=0.7)
axs[1].bar(bar_positions_tko_pb, tko_pb_table['R^2'], color='purple', width=bar_width, label='tKo_pB', alpha=0.7)

axs[1].set_ylabel('Coefficient of determination', fontsize=15)

# Third chart

axs[2].bar(bar_positions_b, b_table['MSE'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[2].bar(bar_positions_ko, ko_table['MSE'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)
axs[2].bar(bar_positions_tb_pko, tb_pko_table['MSE'], color='red', width=bar_width, label='tB_pKo', alpha=0.7)
axs[2].bar(bar_positions_tko_pb, tko_pb_table['MSE'], color='purple', width=bar_width, label='tKo_pB', alpha=0.7)

axs[2].set_ylabel('Mean Squared Error', fontsize=15)

# Get chromosome labels from the 'chr' column
chr_labels = b_table['chr']

# Set x-axis labels for all three subplots
for ax in axs:
    ax.set_xticks(bar_positions_b)
    ax.set_xticklabels(chr_labels)

# Rotate labels for better readability
for ax in axs:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Adjusting layout
plt.tight_layout()

# Place legend outside the subplots and above the last subplot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)

# Show the figure
plt.show()

# %% [markdown]
# # Model trained with information from Brassica crosses to predict recombination on each Broccoli chromosome

# %%
study2.head(2)
# Out:
#                   cross reference   chr   start     end    d  AAA_TTT  \
# 0  broccoli_cauliflower  broccoli  chr1       0  100000  0.0    10211
# 1  broccoli_cauliflower  broccoli  chr1  100000  200000  0.0     8607
#
#    AAC_GTT  AAG_CTT  AAT_ATT  ...  CTA_TAG  CTC_GAG  GAA_TTC  GAC_GTC  \
# 0     4046     3224     6793  ...     2808     2650     4062     1442
# 1     3784     4268     5584  ...     2366     3114     4309     1886
#
#    GCA_TGC  GCC_GGC  GGA_TCC  GTA_TAC  TAA_TTA  TCA_TGA
# 0     1875     1694     2040     2575     5867     3734
# 1     2236     1366     2460     2462     4906     3900
#
# [2 rows x 38 columns]

# %%
all_info_without_broccoli = study2[study2['reference'] != 'broccoli' ]
all_info_without_broccoli
# Out:
#                        cross    reference   chr     start       end        d  \
# 5154    broccoli_cauliflower  cauliflower  chr1         0    100000  0.00000
# 5155    broccoli_cauliflower  cauliflower  chr1    100000    200000  0.00000
# 5156    broccoli_cauliflower  cauliflower  chr1    200000    300000  0.00000
# 5157    broccoli_cauliflower  cauliflower  chr1    300000    400000  0.00000
# 5158    broccoli_cauliflower  cauliflower  chr1    400000    500000  0.36497
# ...                      ...          ...   ...       ...       ...      ...
# 103831        white_kohlrabi     kohlrabi  chr9  64400000  64500000  0.26316
# 103832        white_kohlrabi     kohlrabi  chr9  64500000  64600000  0.00000
# 103833        white_kohlrabi     kohlrabi  chr9  64600000  64700000  0.00000
# 103834        white_kohlrabi     kohlrabi  chr9  64700000  64800000  0.00000
# 103835        white_kohlrabi     kohlrabi  chr9  64800000  64900000  0.00000
#
#         AAA_TTT  AAC_GTT  AAG_CTT  AAT_ATT  ...  CTA_TAG  CTC_GAG  GAA_TTC  \
# 5154       7564     3333     4169     5173  ...     2285     3305     4016
# 5155      10160     4367     3241     6583  ...     3027     2943     4293
# 5156       8720     3912     4245     5593  ...     2392     2934     4243
# 5157       9366     3936     3780     6269  ...     2807     2774     4264
# 5158      10349     4019     3807     6835  ...     2771     2445     4259
# ...         ...      ...      ...      ...  ...      ...      ...      ...
# 103831    11246     4299     3298     7081  ...     3236     2497     4036
# 103832    10101     4700     3424     6216  ...     3550     2464     3793
# 103833     9573     3974     3906     6380  ...     2617     2697     4222
# 103834    10861     4256     3452     7026  ...     3009     2545     4034
# 103835    10274     4087     3565     6577  ...     2821     2681     4143
#
#         GAC_GTC  GCA_TGC  GCC_GGC  GGA_TCC  GTA_TAC  TAA_TTA  TCA_TGA
# 5154       1875     2308     2639     2685     2238     4461     4076
# 5155       1426     1829     1111     2272     2547     5782     3654
# 5156       1854     2192     1313     2436     2592     5015     3900
# 5157       1696     2007     1058     2347     2602     5464     4006
# 5158       1666     1908      912     1951     2584     6213     3981
# ...         ...      ...      ...      ...      ...      ...      ...
# 103831     1427     1941      843     1958     2721     6321     3730
# 103832     1499     1899      856     1995     2509     6623     3638
# 103833     1637     2012     1089     2204     2635     5604     3884
# 103834     1621     1814      814     2014     2587     6326     3948
# 103835     1672     1876     1104     2187     2488     5802     3849
#
# [83223 rows x 38 columns]

# %%
all_info_without_broccoli.reference.unique()
# Out:
# array(['cauliflower', 'kohlrabi', 'kale', 'white'], dtype=object)

# %%
# TRAINING MODEL WITH BRASSICA CROSSES
X_train = all_info_without_broccoli.drop(['cross', 'reference','chr','start','end','d'], axis=1)
y_train = all_info_without_broccoli[['d']]

model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %%
# Objects with Broccoli data per chromosome
chr1 = b[b['chr']== 'chr1']
chr2 = b[b['chr']== 'chr2']
chr3 = b[b['chr']== 'chr3']
chr4 = b[b['chr']== 'chr4']
chr5 = b[b['chr']== 'chr5']
chr6 = b[b['chr']== 'chr6']
chr7 = b[b['chr']== 'chr7']
chr8 = b[b['chr']== 'chr8']
chr9 = b[b['chr']== 'chr9']

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chromosomes_data = globals()[f'achr{chr_number}']
    chr_data = globals()[f'chr{chr_number}']

    # MODEL PREDICTIONS
    model_preds = model.predict(chr_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['srec'].iloc[0:c_q1]
    rq2 = chr_data['srec'].iloc[c_q1:c_q2]
    rq3 = chr_data['srec'].iloc[c_q2:c_q3]
    rq4 = chr_data['srec'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.srec, label='Recombination')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'Broccoli Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('chromosomes position (Mb)', fontsize=15)
    ax1.set_ylabel('Recombination rate (cM/100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.srec, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Recombination vs. Prediction', fontsize=15)
    ax2.set_xlabel('Recombination', fontsize=15)
    ax2.set_ylabel('Prediction', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.srec, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.srec, model_spreds)
    mse_chr = mean_squared_error(chr_data.srec, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.1)
    plt.show()

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 10):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7,corr_chr8,corr_chr9,]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9',]})
ta_pb_table = pd.concat([index, corr, r2, mse], axis=1)
ta_pb_table
# Out:
#     chr      corr       R^2       MSE
# 0  chr1  0.827716  0.528719  0.006941
# 1  chr2  0.836997  0.557198  0.003672
# 2  chr3  0.662615  0.424724  0.003292
# 3  chr4  0.831921  0.529960  0.004506
# 4  chr5  0.779923  0.432951  0.014317
# 5  chr6  0.898259  0.641723  0.003501
# 6  chr7  0.874427  0.661603  0.002419
# 7  chr8  0.862761  0.681516  0.002375
# 8  chr9  0.886817  0.623669  0.005528

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_f0458 th {
#   text-align: center;
# }
# #T_f0458_row0_col1, #T_f0458_row1_col1 {
#   background-color: #146b30;
#   color: #f1f1f1;
# }
# #T_f0458_row0_col2 {
#   background-color: #197535;
#   color: #f1f1f1;
# }
# #T_f0458_row0_col3 {
#   background-color: #cdebc7;
#   color: #000000;
# }
# #T_f0458_row0_col4 {
#   background-color: #37904a;
#   color: #f1f1f1;
# }
# #T_f0458_row1_col2 {
#   background-color: #f2edf3;
#   color: #000000;
# }
# #T_f0458_row1_col3 {
#   background-color: #ebdcec;
#   color: #000000;
# }
# #T_f0458_row1_col4, #T_f0458_row3_col2 {
#   background-color: #58ac5f;
#   color: #f1f1f1;
# }
# #T_f0458_row2_col1 {
#   background-color: #3f974f;
#   color: #f1f1f1;
# }
# #T_f0458_row2_col2, #T_f0458_row4_col1 {
#   background-color: #3c954d;
#   color: #f1f1f1;
# }
# #T_f0458_row2_col3, #T_f0458_row7_col2 {
#   background-color: #1a7736;
#   color: #f1f1f1;
# }
# #T_f0458_row2_col4 {
#   background-color: #afdfa9;
#   color: #000000;
# }
# #T_f0458_row3_col1 {
#   background-color: #60b266;
#   color: #f1f1f1;
# }
# #T_f0458_row3_col3 {
#   background-color: #c5e8bf;
#   color: #000000;
# }
# #T_f0458_row3_col4, #T_f0458_row8_col1 {
#   background-color: #0e5f29;
#   color: #f1f1f1;
# }
# #T_f0458_row4_col2 {
#   background-color: #c3e7bd;
#   color: #000000;
# }
# #T_f0458_row4_col3 {
#   background-color: #e6f3e3;
#   color: #000000;
# }
# #T_f0458_row4_col4, #T_f0458_row8_col4 {
#   background-color: #11652d;
#   color: #f1f1f1;
# }
# #T_f0458_row5_col1 {
#   background-color: #8aca89;
#   color: #000000;
# }
# #T_f0458_row5_col2 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_f0458_row5_col3 {
#   background-color: #7bc17c;
#   color: #000000;
# }
# #T_f0458_row5_col4 {
#   background-color: #0b5826;
#   color: #f1f1f1;
# }
# #T_f0458_row6_col1 {
#   background-color: #f7f6f7;
#   color: #000000;
# }
# #T_f0458_row6_col2 {
#   background-color: #e2f2de;
#   color: #000000;
# }
# #T_f0458_row6_col3 {
#   background-color: #55aa5e;
#   color: #f1f1f1;
# }
# #T_f0458_row6_col4 {
#   background-color: #247f3d;
#   color: #f1f1f1;
# }
# #T_f0458_row7_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_f0458_row7_col3 {
#   background-color: #449b52;
#   color: #f1f1f1;
# }
# #T_f0458_row7_col4 {
#   background-color: #5db063;
#   color: #f1f1f1;
# }
# #T_f0458_row8_col2 {
#   background-color: #f1f5ef;
#   color: #000000;
# }
# #T_f0458_row8_col3 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# </style>
# <table id="T_f0458">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0458_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_f0458_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_f0458_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_f0458_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_f0458_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0458_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0458_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_f0458_row0_col1" class="data row0 col1" >0.849979</td>
#       <td id="T_f0458_row0_col2" class="data row0 col2" >0.810220</td>
#       <td id="T_f0458_row0_col3" class="data row0 col3" >0.248219</td>
#       <td id="T_f0458_row0_col4" class="data row0 col4" >0.705077</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0458_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_f0458_row1_col1" class="data row1 col1" >0.844017</td>
#       <td id="T_f0458_row1_col2" class="data row1 col2" >-0.056982</td>
#       <td id="T_f0458_row1_col3" class="data row1 col3" >-0.154835</td>
#       <td id="T_f0458_row1_col4" class="data row1 col4" >0.606628</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0458_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_f0458_row2_col1" class="data row2 col1" >0.684748</td>
#       <td id="T_f0458_row2_col2" class="data row2 col2" >0.692812</td>
#       <td id="T_f0458_row2_col3" class="data row2 col3" >0.798028</td>
#       <td id="T_f0458_row2_col4" class="data row2 col4" >0.364637</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0458_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_f0458_row3_col1" class="data row3 col1" >0.583138</td>
#       <td id="T_f0458_row3_col2" class="data row3 col2" >0.603021</td>
#       <td id="T_f0458_row3_col3" class="data row3 col3" >0.279535</td>
#       <td id="T_f0458_row3_col4" class="data row3 col4" >0.897644</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0458_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_f0458_row4_col1" class="data row4 col1" >0.690661</td>
#       <td id="T_f0458_row4_col2" class="data row4 col2" >0.284527</td>
#       <td id="T_f0458_row4_col3" class="data row4 col3" >0.111902</td>
#       <td id="T_f0458_row4_col4" class="data row4 col4" >0.868723</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f0458_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_f0458_row5_col1" class="data row5 col1" >0.471726</td>
#       <td id="T_f0458_row5_col2" class="data row5 col2" >0.201562</td>
#       <td id="T_f0458_row5_col3" class="data row5 col3" >0.509733</td>
#       <td id="T_f0458_row5_col4" class="data row5 col4" >0.919545</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f0458_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_f0458_row6_col1" class="data row6 col1" >-0.000088</td>
#       <td id="T_f0458_row6_col2" class="data row6 col2" >0.135820</td>
#       <td id="T_f0458_row6_col3" class="data row6 col3" >0.611824</td>
#       <td id="T_f0458_row6_col4" class="data row6 col4" >0.772161</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f0458_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_f0458_row7_col1" class="data row7 col1" >0.186723</td>
#       <td id="T_f0458_row7_col2" class="data row7 col2" >0.803444</td>
#       <td id="T_f0458_row7_col3" class="data row7 col3" >0.664164</td>
#       <td id="T_f0458_row7_col4" class="data row7 col4" >0.588609</td>
#     </tr>
#     <tr>
#       <th id="T_f0458_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f0458_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_f0458_row8_col1" class="data row8 col1" >0.891086</td>
#       <td id="T_f0458_row8_col2" class="data row8 col2" >0.043677</td>
#       <td id="T_f0458_row8_col3" class="data row8 col3" >0.389146</td>
#       <td id="T_f0458_row8_col4" class="data row8 col4" >0.867544</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Model trained with information from Brassica crosses to predict recombination on each Kohlrabi chromosome

# %%
all_info_without_kohlrabi = study2[study2['reference'] != 'kohlrabi' ]
all_info_without_kohlrabi
# Out:
#                       cross reference   chr     start       end        d  \
# 0      broccoli_cauliflower  broccoli  chr1         0    100000  0.00000
# 1      broccoli_cauliflower  broccoli  chr1    100000    200000  0.00000
# 2      broccoli_cauliflower  broccoli  chr1    200000    300000  0.00000
# 3      broccoli_cauliflower  broccoli  chr1    300000    400000  0.36497
# 4      broccoli_cauliflower  broccoli  chr1    400000    500000  0.00000
# ...                     ...       ...   ...       ...       ...      ...
# 98622        white_kohlrabi     white  chr9  65200000  65300000  0.00000
# 98623        white_kohlrabi     white  chr9  65300000  65400000  0.26316
# 98624        white_kohlrabi     white  chr9  65400000  65500000  0.00000
# 98625        white_kohlrabi     white  chr9  65500000  65600000  0.00000
# 98626        white_kohlrabi     white  chr9  65600000  65700000  0.00000
#
#        AAA_TTT  AAC_GTT  AAG_CTT  AAT_ATT  ...  CTA_TAG  CTC_GAG  GAA_TTC  \
# 0        10211     4046     3224     6793  ...     2808     2650     4062
# 1         8607     3784     4268     5584  ...     2366     3114     4309
# 2         9715     4085     3807     6370  ...     2876     2681     4269
# 3         9583     3997     3850     6207  ...     2730     2744     4189
# 4         9883     3941     4052     6189  ...     2442     2812     4330
# ...        ...      ...      ...      ...  ...      ...      ...      ...
# 98622    13046     4398     2857     7986  ...     3445     2265     4104
# 98623    10420     4296     3396     6915  ...     3050     2620     4143
# 98624     9892     4080     3727     6619  ...     2684     2541     4223
# 98625    10062     4108     3840     6310  ...     2625     2669     4241
# 98626    11053     4214     3150     7142  ...     3315     2567     4085
#
#        GAC_GTC  GCA_TGC  GCC_GGC  GGA_TCC  GTA_TAC  TAA_TTA  TCA_TGA
# 0         1442     1875     1694     2040     2575     5867     3734
# 1         1886     2236     1366     2460     2462     4906     3900
# 2         1608     1965     1048     2261     2642     5753     3912
# 3         1819     2026     1100     2224     2473     5611     3977
# 4         1819     1813     1146     2323     2409     5599     3867
# ...        ...      ...      ...      ...      ...      ...      ...
# 98622     1209     1700      583     1649     2820     6948     3659
# 98623     1553     2070      838     1981     2537     6140     3933
# 98624     1620     1950     1032     2151     2656     5853     3810
# 98625     1817     1906     1022     2236     2582     5725     3886
# 98626     1368     1683      971     1973     2526     6182     3946
#
# [82980 rows x 38 columns]

# %%
all_info_without_kohlrabi.reference.unique()
# Out:
# array(['broccoli', 'cauliflower', 'kale', 'white'], dtype=object)

# %%
# TRAINING MODEL WITH BRASSICA CROSSES
X_train = all_info_without_kohlrabi.drop(['cross', 'reference','chr','start','end','d'], axis=1)
y_train = all_info_without_kohlrabi[['d']]

model.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %%
# Objects with Kohlrabi data per chromosome
chr1 = ko[ko['chr']== 'chr1']
chr2 = ko[ko['chr']== 'chr3']
chr4 = ko[ko['chr']== 'chr4']
chr5 = ko[ko['chr']== 'chr5']
chr6 = ko[ko['chr']== 'chr6']
chr7 = ko[ko['chr']== 'chr7']
chr8 = ko[ko['chr']== 'chr8']
chr9 = ko[ko['chr']== 'chr9']

# %%
def plot_chromosome_results(chr_number):
    # Replace  with 'chr{chr_number}' 
    chromosomes_data = globals()[f'achr{chr_number}']
    chr_data = globals()[f'chr{chr_number}']

    # MODEL PREDICTIONS
    model_preds = model.predict(chr_data.drop(['cross', 'reference','chr','start','end','d','srec'], axis=1))
    
    #SMOOTHING
    model_preds = pd.DataFrame(model_preds, columns=['model_preds']) 
    model_spreds = gaussian_filter(model_preds['model_preds'], sigma= 3)
        
    #CORRELATIONS BY QUARTILES
    c_q1 = int(len(chr_data)*0.25)
    c_q2 = int(len(chr_data)*0.50)
    c_q3 = int(len(chr_data)*0.75)
    
    rq1 = chr_data['srec'].iloc[0:c_q1]
    rq2 = chr_data['srec'].iloc[c_q1:c_q2]
    rq3 = chr_data['srec'].iloc[c_q2:c_q3]
    rq4 = chr_data['srec'].iloc[c_q3:int(len(chr_data))]

    pq1 = model_spreds[0:c_q1]
    pq2 = model_spreds[c_q1:c_q2]
    pq3 = model_spreds[c_q2:c_q3]
    pq4 = model_spreds[c_q3:int(len(chr_data))]

    corr_q1 = np.corrcoef(rq1, pq1)[0, 1]
    corr_q2 = np.corrcoef(rq2, pq2)[0, 1]
    corr_q3 = np.corrcoef(rq3, pq3)[0, 1]
    corr_q4 = np.corrcoef(rq4, pq4)[0, 1]
    
    globals()[f'corr_q1_chr{chr_number}'] = corr_q1
    globals()[f'corr_q2_chr{chr_number}'] = corr_q2
    globals()[f'corr_q3_chr{chr_number}'] = corr_q3
    globals()[f'corr_q4_chr{chr_number}'] = corr_q4
     
    # PLOTTING RESULTS
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 4), gridspec_kw={'width_ratios': [10, 3]})

    # Line plot and correlation plot
    ax1.plot(chr_data.end, chr_data.srec, label='Recombination')
    ax1.plot(chr_data.end, model_spreds, label='Prediction', color='green')
    ax1.set_title(f'Kohlrabi Chromosome {chr_number}', fontsize=20)
    ax1.set_xlabel('chromosomes position (Mb)', fontsize=15)
    ax1.set_ylabel('Recombination rate (cM/100kb)', fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ticks = ax1.get_xticks() / 1000000
    ax1.set_xticklabels(ticks)
        
    chr_len = chr_data["end"].iloc[-1]
    q1 =round(chr_len * 0.25 / 100000) * 100000
    q2 =round(chr_len* 0.50 / 100000) * 100000
    q3 =round(chr_len * 0.75 / 100000) * 100000

    ax1.axvline(x=q1, color='gray', linestyle='-')
    ax1.axvline(x=q2, color='gray', linestyle='--')
    ax1.axvline(x=q3, color='gray', linestyle='-')

    # Scatter plot
    scatter = ax2.scatter(chr_data.srec, model_spreds, c='skyblue', edgecolors='black', linewidth= 0.3)
    ax2.set_title('Recombination vs. Prediction', fontsize=15)
    ax2.set_xlabel('Recombination', fontsize=15)
    ax2.set_ylabel('Prediction', fontsize=15)

    # Calculate correlation coefficient, coefficient of determination, and Mean Squared Error
    corr_chr = np.corrcoef(chr_data.srec, model_spreds)[0, 1]
    r2_chr = r2_score(chr_data.srec, model_spreds)
    mse_chr = mean_squared_error(chr_data.srec, model_spreds)

    # Calculate the aspect ratio based on the plot heights
    h1 = ax1.get_ylim()
    h2 = ax2.get_ylim()
    aspect_ratio = max(h1[1] - h1[0], h2[1] - h2[0]) / (max(h1[1], h2[1]) - min(h1[0], h2[0]))

    # Set the aspect ratio for the scatter plot only if it doesn't distort the square shape
    if aspect_ratio < 1:
        ax2.set_aspect('equal')

    # Display correlation coefficient, coefficient of determination, and Mean Squared Error as plain text
    globals()[f'corr_chr{chr_number}'] = corr_chr
    globals()[f'r2_chr{chr_number}'] = r2_chr
    globals()[f'mse_chr{chr_number}'] = mse_chr

    textstr = f'Correlation: {corr_chr:.3f}\nR-squared: {r2_chr:.3f}\nMSE: {mse_chr:.3f}'
    ax2.text(0.05, 0.95, textstr, transform=ax2.transAxes, fontsize=12, verticalalignment='top', horizontalalignment='left')

    # Adjustments to align the heights of the two plots
    max_height = max(h1[1], h2[1])
    ax1.set_ylim([h1[0], max_height])
    ax2.set_ylim([h2[0], max_height])

    # Reduce the separation between the plots
    plt.subplots_adjust(wspace=0.1)
    plt.show()

# %%
# Predictions and graphs for all chromosomes
for chr_number in range(1, 10):
    plot_chromosome_results(chr_number)
    plt.show()

# %% [markdown]
# # Data compilation

# %%
corr = pd.DataFrame({'corr':[corr_chr1, corr_chr2, corr_chr3, corr_chr4, corr_chr5, corr_chr6,corr_chr7,corr_chr8,corr_chr9,]})
r2 = pd.DataFrame({'R^2':[r2_chr1, r2_chr2, r2_chr3, r2_chr4, r2_chr5, r2_chr6, r2_chr7, r2_chr8, r2_chr9]})
mse = pd.DataFrame({'MSE':[mse_chr1, mse_chr2, mse_chr3, mse_chr4, mse_chr5, mse_chr6, mse_chr7, mse_chr8, mse_chr9]})
index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9',]})
ta_pko_table = pd.concat([index, corr, r2, mse], axis=1)
ta_pko_table
# Out:
#     chr      corr       R^2       MSE
# 0  chr1  0.858857  0.533404  0.006971
# 1  chr2  0.651197  0.422589  0.003094
# 2  chr3  0.890472  0.784717  0.001232
# 3  chr4  0.845830  0.559697  0.004039
# 4  chr5  0.801341  0.447325  0.013792
# 5  chr6  0.822089  0.549621  0.004092
# 6  chr7  0.871305  0.658777  0.002218
# 7  chr8  0.846999  0.658538  0.002577
# 8  chr9  0.866750  0.599259  0.005458

# %%
corr_q1 = pd.DataFrame({'Q1':[corr_q1_chr1,corr_q1_chr2,corr_q1_chr3,corr_q1_chr4,corr_q1_chr5,corr_q1_chr6,corr_q1_chr7,corr_q1_chr8,corr_q1_chr9]})
corr_q2 = pd.DataFrame({'Q2':[corr_q2_chr1,corr_q2_chr2,corr_q2_chr3,corr_q2_chr4,corr_q2_chr5,corr_q2_chr6,corr_q2_chr7,corr_q2_chr8,corr_q2_chr9]})
corr_q3 = pd.DataFrame({'Q3':[corr_q3_chr1,corr_q3_chr2,corr_q3_chr3,corr_q3_chr4,corr_q3_chr5,corr_q3_chr6,corr_q3_chr7,corr_q3_chr8,corr_q3_chr9]})
corr_q4 = pd.DataFrame({'Q4':[corr_q4_chr1,corr_q4_chr2,corr_q4_chr3,corr_q4_chr4,corr_q4_chr5,corr_q4_chr6,corr_q4_chr7,corr_q4_chr8,corr_q4_chr9]})

index = pd.DataFrame({'chr':['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9']})
q_corr = pd.concat([index, corr_q1, corr_q2, corr_q3, corr_q4], axis=1)
q_corr_styled = q_corr.style.background_gradient(cmap="PRGn", vmin=-1, vmax=1)
q_corr_styled.set_table_styles([{'selector': 'th',
                                'props': [('text-align', 'center')]}])
q_corr_styled
# Out:
# <style type="text/css">
# #T_94c97 th {
#   text-align: center;
# }
# #T_94c97_row0_col1 {
#   background-color: #0f612a;
#   color: #f1f1f1;
# }
# #T_94c97_row0_col2 {
#   background-color: #328c47;
#   color: #f1f1f1;
# }
# #T_94c97_row0_col3 {
#   background-color: #e8f4e5;
#   color: #000000;
# }
# #T_94c97_row0_col4 {
#   background-color: #1c7938;
#   color: #f1f1f1;
# }
# #T_94c97_row1_col1 {
#   background-color: #358e48;
#   color: #f1f1f1;
# }
# #T_94c97_row1_col2, #T_94c97_row4_col1, #T_94c97_row7_col2 {
#   background-color: #308a45;
#   color: #f1f1f1;
# }
# #T_94c97_row1_col3 {
#   background-color: #37904a;
#   color: #f1f1f1;
# }
# #T_94c97_row1_col4 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_94c97_row2_col1, #T_94c97_row2_col4 {
#   background-color: #10632b;
#   color: #f1f1f1;
# }
# #T_94c97_row2_col2 {
#   background-color: #12672e;
#   color: #f1f1f1;
# }
# #T_94c97_row2_col3 {
#   background-color: #0c5a27;
#   color: #f1f1f1;
# }
# #T_94c97_row3_col1 {
#   background-color: #2e8843;
#   color: #f1f1f1;
# }
# #T_94c97_row3_col2 {
#   background-color: #4ea359;
#   color: #f1f1f1;
# }
# #T_94c97_row3_col3, #T_94c97_row4_col2 {
#   background-color: #c9e9c3;
#   color: #000000;
# }
# #T_94c97_row3_col4 {
#   background-color: #13692f;
#   color: #f1f1f1;
# }
# #T_94c97_row4_col3 {
#   background-color: #cdebc7;
#   color: #000000;
# }
# #T_94c97_row4_col4 {
#   background-color: #0b5826;
#   color: #f1f1f1;
# }
# #T_94c97_row5_col1 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_94c97_row5_col2 {
#   background-color: #66b56b;
#   color: #f1f1f1;
# }
# #T_94c97_row5_col3 {
#   background-color: #53a85c;
#   color: #f1f1f1;
# }
# #T_94c97_row5_col4 {
#   background-color: #1a7736;
#   color: #f1f1f1;
# }
# #T_94c97_row6_col1 {
#   background-color: #eee3ee;
#   color: #000000;
# }
# #T_94c97_row6_col2, #T_94c97_row8_col2 {
#   background-color: #b3e0ad;
#   color: #000000;
# }
# #T_94c97_row6_col3 {
#   background-color: #87c886;
#   color: #000000;
# }
# #T_94c97_row6_col4 {
#   background-color: #1f7b39;
#   color: #f1f1f1;
# }
# #T_94c97_row7_col1 {
#   background-color: #f2f6f1;
#   color: #000000;
# }
# #T_94c97_row7_col3 {
#   background-color: #449b52;
#   color: #f1f1f1;
# }
# #T_94c97_row7_col4 {
#   background-color: #4ba157;
#   color: #f1f1f1;
# }
# #T_94c97_row8_col1, #T_94c97_row8_col4 {
#   background-color: #11652d;
#   color: #f1f1f1;
# }
# #T_94c97_row8_col3 {
#   background-color: #addea7;
#   color: #000000;
# }
# </style>
# <table id="T_94c97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94c97_level0_col0" class="col_heading level0 col0" >chr</th>
#       <th id="T_94c97_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_94c97_level0_col2" class="col_heading level0 col2" >Q2</th>
#       <th id="T_94c97_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_94c97_level0_col4" class="col_heading level0 col4" >Q4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94c97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94c97_row0_col0" class="data row0 col0" >chr1</td>
#       <td id="T_94c97_row0_col1" class="data row0 col1" >0.884331</td>
#       <td id="T_94c97_row0_col2" class="data row0 col2" >0.724220</td>
#       <td id="T_94c97_row0_col3" class="data row0 col3" >0.098851</td>
#       <td id="T_94c97_row0_col4" class="data row0 col4" >0.790041</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94c97_row1_col0" class="data row1 col0" >chr2</td>
#       <td id="T_94c97_row1_col1" class="data row1 col1" >0.711947</td>
#       <td id="T_94c97_row1_col2" class="data row1 col2" >0.728704</td>
#       <td id="T_94c97_row1_col3" class="data row1 col3" >0.708060</td>
#       <td id="T_94c97_row1_col4" class="data row1 col4" >0.388228</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94c97_row2_col0" class="data row2 col0" >chr3</td>
#       <td id="T_94c97_row2_col1" class="data row2 col1" >0.875294</td>
#       <td id="T_94c97_row2_col2" class="data row2 col2" >0.865467</td>
#       <td id="T_94c97_row2_col3" class="data row2 col3" >0.906279</td>
#       <td id="T_94c97_row2_col4" class="data row2 col4" >0.876193</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94c97_row3_col0" class="data row3 col0" >chr4</td>
#       <td id="T_94c97_row3_col1" class="data row3 col1" >0.734637</td>
#       <td id="T_94c97_row3_col2" class="data row3 col2" >0.640193</td>
#       <td id="T_94c97_row3_col3" class="data row3 col3" >0.262018</td>
#       <td id="T_94c97_row3_col4" class="data row3 col4" >0.853454</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94c97_row4_col0" class="data row4 col0" >chr5</td>
#       <td id="T_94c97_row4_col1" class="data row4 col1" >0.731730</td>
#       <td id="T_94c97_row4_col2" class="data row4 col2" >0.264616</td>
#       <td id="T_94c97_row4_col3" class="data row4 col3" >0.243207</td>
#       <td id="T_94c97_row4_col4" class="data row4 col4" >0.914379</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94c97_row5_col0" class="data row5 col0" >chr6</td>
#       <td id="T_94c97_row5_col1" class="data row5 col1" >0.228024</td>
#       <td id="T_94c97_row5_col2" class="data row5 col2" >0.566935</td>
#       <td id="T_94c97_row5_col3" class="data row5 col3" >0.620911</td>
#       <td id="T_94c97_row5_col4" class="data row5 col4" >0.797060</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94c97_row6_col0" class="data row6 col0" >chr7</td>
#       <td id="T_94c97_row6_col1" class="data row6 col1" >-0.109444</td>
#       <td id="T_94c97_row6_col2" class="data row6 col2" >0.347324</td>
#       <td id="T_94c97_row6_col3" class="data row6 col3" >0.482256</td>
#       <td id="T_94c97_row6_col4" class="data row6 col4" >0.786839</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94c97_row7_col0" class="data row7 col0" >chr8</td>
#       <td id="T_94c97_row7_col1" class="data row7 col1" >0.032864</td>
#       <td id="T_94c97_row7_col2" class="data row7 col2" >0.731151</td>
#       <td id="T_94c97_row7_col3" class="data row7 col3" >0.669246</td>
#       <td id="T_94c97_row7_col4" class="data row7 col4" >0.646031</td>
#     </tr>
#     <tr>
#       <th id="T_94c97_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94c97_row8_col0" class="data row8 col0" >chr9</td>
#       <td id="T_94c97_row8_col1" class="data row8 col1" >0.871641</td>
#       <td id="T_94c97_row8_col2" class="data row8 col2" >0.344768</td>
#       <td id="T_94c97_row8_col3" class="data row8 col3" >0.368542</td>
#       <td id="T_94c97_row8_col4" class="data row8 col4" >0.873212</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Comparison of the six models

# %%
# Adjusting bar width
bar_width = 0.15

# Creating data positions
bar_positions_b = np.arange(len(b_table['chr']))
bar_positions_ko = bar_positions_b + bar_width
bar_positions_tb_pko = bar_positions_ko + bar_width
bar_positions_tko_pb = bar_positions_tb_pko + bar_width
bar_positions_ta_pb = bar_positions_tko_pb + bar_width
bar_positions_ta_pko = bar_positions_ta_pb + bar_width

# Creating subplots (1 row, 3 columns)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# First chart
axs[0].bar(bar_positions_b, b_table['corr'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[0].bar(bar_positions_ko, ko_table['corr'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)
axs[0].bar(bar_positions_tb_pko, tb_pko_table['corr'], color='red', width=bar_width, label='tB_pKo', alpha=0.7)
axs[0].bar(bar_positions_tko_pb, tko_pb_table['corr'], color='purple', width=bar_width, label='tKo_pB', alpha=0.7)
axs[0].bar(bar_positions_ta_pb, ta_pb_table['corr'], color='darkorange', width=bar_width, label='tA_pB', alpha=0.7)
axs[0].bar(bar_positions_ta_pko, ta_pko_table['corr'], color='darkblue', width=bar_width, label='tA_pKo', alpha=0.7)

axs[0].set_ylabel('Correlation', fontsize=15)

# Second chart
axs[1].bar(bar_positions_b, b_table['R^2'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[1].bar(bar_positions_ko, ko_table['R^2'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)
axs[1].bar(bar_positions_tb_pko, tb_pko_table['R^2'], color='red', width=bar_width, label='tB_pKo', alpha=0.7)
axs[1].bar(bar_positions_tko_pb, tko_pb_table['R^2'], color='purple', width=bar_width, label='tKo_pB', alpha=0.7)
axs[1].bar(bar_positions_ta_pb, ta_pb_table['R^2'], color='darkorange', width=bar_width, label='tA_pB', alpha=0.7)
axs[1].bar(bar_positions_ta_pko, ta_pko_table['R^2'], color='darkblue', width=bar_width, label='tA_pKo', alpha=0.7)

axs[1].set_ylabel('Coefficient of determination', fontsize=15)

# Third chart

axs[2].bar(bar_positions_b, b_table['MSE'], color='dodgerblue', width=bar_width, label='Broccoli', alpha=0.7)
axs[2].bar(bar_positions_ko, ko_table['MSE'], color='limegreen', width=bar_width, label='Kohlrabi', alpha=0.7)
axs[2].bar(bar_positions_tb_pko, tb_pko_table['MSE'], color='red', width=bar_width, label='tB_pKo', alpha=0.7)
axs[2].bar(bar_positions_tko_pb, tko_pb_table['MSE'], color='purple', width=bar_width, label='tKo_pB', alpha=0.7)
axs[2].bar(bar_positions_ta_pb, ta_pb_table['MSE'], color='darkorange', width=bar_width, label='tA_pB', alpha=0.7)
axs[2].bar(bar_positions_ta_pko, ta_pko_table['MSE'], color='darkblue', width=bar_width, label='tA_pKo', alpha=0.7)

axs[2].set_ylabel('Mean Squared Error', fontsize=15)

# Get chromosome labels from the 'chr' column
chr_labels = b_table['chr']

# Set x-axis labels for all three subplots
for ax in axs:
    ax.set_xticks(bar_positions_b)
    ax.set_xticklabels(chr_labels)

# Rotate labels for better readability
for ax in axs:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Adjusting layout
plt.tight_layout()

# Place legend outside the subplots and above the last subplot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=12)

# Show the figure
plt.show()

# %%
summary = {'Training_set': ['Broccoli', 'Kohlrabi', 'Broccoli', 'Kohlrabi', 'All_except_Broccoli', 'All_except_Kohlrabi'],
           'Testing_set': ['Broccoli', 'Kohlrabi', 'Kohlrabi', 'Broccoli', 'Broccoli', 'Kohlrabi', ],
           'corr': [b_table.describe().iloc[1,0].round(3), ko_table.describe().iloc[1,0].round(3), tb_pko_table.describe().iloc[1,0].round(3), tko_pb_table.describe().iloc[1,0].round(3), ta_pb_table.describe().iloc[1,0].round(3), ta_pko_table.describe().iloc[1,0].round(3)],
           'R^2': [b_table.describe().iloc[1,1].round(3), ko_table.describe().iloc[1,1].round(3), tb_pko_table.describe().iloc[1,1].round(3), tko_pb_table.describe().iloc[1,1].round(3), ta_pb_table.describe().iloc[1,1].round(3), ta_pko_table.describe().iloc[1,1].round(3)],
           'MSE': [b_table.describe().iloc[1,2].round(3), ko_table.describe().iloc[1,2].round(3), tb_pko_table.describe().iloc[1,2].round(3), tko_pb_table.describe().iloc[1,2].round(3), ta_pb_table.describe().iloc[1,2].round(3), ta_pko_table.describe().iloc[1,2].round(3)]}

summary = pd.DataFrame(summary)
summary
# Out:
#           Training_set Testing_set   corr    R^2    MSE
# 0             Broccoli    Broccoli  0.785  0.516  0.006
# 1             Kohlrabi    Kohlrabi  0.755  0.478  0.006
# 2             Broccoli    Kohlrabi  0.797  0.540  0.005
# 3             Kohlrabi    Broccoli  0.800  0.540  0.005
# 4  All_except_Broccoli    Broccoli  0.829  0.565  0.005
# 5  All_except_Kohlrabi    Kohlrabi  0.828  0.579  0.005

# %%
summary.to_csv('./output/performance_models_broccoli_kohlrabi_kmers.csv', index = None)
